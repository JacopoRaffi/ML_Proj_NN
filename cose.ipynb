# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as mplt

# %%
template_df = pd.read_csv(
    './data/ML-CUP23-Template_example.csv',
    index_col=0,
    comment='#',
    header=None,
    names=['output_' + str(i+1) for i in range(3)]
)
training_df = pd.read_csv(
    './data/ML-CUP23-TR.csv',
    index_col=0,
    comment='#',
    header=None,
    names=['feature_' + str(i+1) for i in range(10)] + ['target_' + str(i+1) for i in range(3)]
)
test_df = pd.read_csv(
    './data/ML-CUP23-TS.csv',
    index_col=0,
    comment='#',
    header=None,
    names=['feature_' + str(i+1) for i in range(10)] + ['target_' + str(i+1) for i in range(3)]
)

# %%
template_df
# Out:
#      output_1  output_2  output_3
# 1    1.915904  0.212668  0.684236
# 2    1.103125 -1.261726 -0.901910
# 3    1.340905  0.434405  0.089518
# 4   -0.749779 -1.801421 -3.903212
# 5   -0.734681 -0.687498  0.891755
# ..        ...       ...       ...
# 896  1.158181 -0.893544 -1.097131
# 897  0.594102  0.168081  0.657830
# 898 -0.114886  0.273791 -0.787928
# 899  0.041023 -0.505206 -2.640435
# 900 -0.858146 -1.000909 -1.355295
#
# [900 rows x 3 columns]

# %%
fig, ax = mplt.subplots(figsize=(15, 5))
sns.violinplot(data=training_df,ax=ax)
ax.set_yscale('symlog')

# %%
fig, ax = mplt.subplots(figsize=(15, 15))
pd.plotting.scatter_matrix(training_df, ax=ax);
# Out:
# C:\Users\Geco\AppData\Local\Temp\ipykernel_21872\2390102557.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(training_df, ax=ax);

# %%
fig, ax = mplt.subplots(figsize=(15, 15))
sns.heatmap(data=training_df.corr(), vmin=-1, vmax=1, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
dummy_ser = training_df['feature_5'].to_frame().sort_values(by=['feature_5'], axis=0)
dummy_ser
# Out:
#      feature_5
# 209  -0.984356
# 493  -0.983380
# 18   -0.981792
# 90   -0.980749
# 55   -0.979294
# ..         ...
# 319   0.998750
# 417   0.998769
# 505   0.998792
# 104   0.998792
# 650   0.998807
#
# [1000 rows x 1 columns]

# %%
mplt.scatter(range(1000), dummy_ser['feature_5'])
