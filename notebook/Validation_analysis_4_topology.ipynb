# %%
import sys
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import ast

sys.path.append(os.path.abspath('../src/'))
from ActivationFunctions import *
from NeuralNetwork import *
from MyUtils import *
from ModelSelection import *

# %matplotlib inline

# %%
tr_norm_df = pd.read_csv('../data/divided_std_train_0_8.csv')
test_norm_df = pd.read_csv('../data/divided_std_test_0_2.csv')

tr_df = pd.read_csv('../data/divided_train_0_8.csv')
test_df = pd.read_csv('../data/divided_test_0_2.csv')

TR_INPUT = 10
TR_OUTPUT = 3

tr_normalized = tr_norm_df.values
test_normalized = test_norm_df.values
training_set = tr_df.values
test_set = test_df.values

scaler_out = StandardScaler()
scaler_out.fit(tr_normalized[:,TR_INPUT:])

training_len = len(tr_norm_df)
test_len = len(test_norm_df)

# %%
def remove_useless_val(x):
    a =['learning_rate', 'lr_decay_tau', 'alpha_momentum']
    b =['adamax_learning_rate', 'exp_decay_rate_1', 'exp_decay_rate_2']
    if x['adamax']:
        for i in a:
            if i in x.keys():
                x[i] = None
    else:
        for i in b:
            if i in x.keys():
                x[i] = None   
    return x

# %%
columns_order = ['topology', 'stats',
 'batch_size',
 'min_epochs',
 'max_epochs',
 'patience',
 'error_increase_tolerance',
 'lambda_tikhonov',
 
 'learning_rate',
 'alpha_momentum',
 'lr_decay_tau',
 
 'adamax',
 'adamax_learning_rate',
 'exp_decay_rate_1',
 'exp_decay_rate_2',
 
 'mean_mean_euclidean_error',
 'mean_mean_squared_error',
 'var_mean_euclidean_error',
 'var_mean_squared_error',
 'mean_best_validation_training_error']

# %%
results_files = ['multy_topology_sigmoid_4.csv']
topologies = ['wrong']
folder = '../data/gs_data/'
topologies_dict = {}
gs_results = []
names = ['20_sigmoid', '6_6_6_sigmoid', '12_12_sigmoid', '12_sigmoid', '40_sigmoid']
for i, f in enumerate(results_files):
    if os.path.isfile(folder+ f):
        dummy = pd.read_csv(folder + f)
        topologies_dict[topologies[i]] = ast.literal_eval(dummy['topology'][0])
        dummy['topology'] = ['20_sigmoid', '6_6_6_sigmoid', '12_12_sigmoid', '12_sigmoid', '40_sigmoid']

        gs_results.append(dummy)
    

orig_df = pd.concat(gs_results)
orig_df
# Out:
#    adamax  alpha_momentum  batch_size  error_increase_tolerance  \
# 0   False             0.9          10                   0.00001
# 1   False             0.9          10                   0.00001
# 2   False             0.9          10                   0.00001
# 3   False             0.9          10                   0.00001
# 4   False             0.9          10                   0.00001
#
#    lambda_tikhonov  learning_rate  lr_decay_tau  max_epochs  min_epochs  \
# 0         0.000001            0.1           175         600         100
# 1         0.000001            0.1           175         600         100
# 2         0.000001            0.1           175         600         100
# 3         0.000001            0.1           175         600         100
# 4         0.000001            0.1           175         600         100
#
#    patience       topology                                              stats  \
# 0         5     20_sigmoid  {'error_increase_tolerance': 1e-05, 'exp_decay...
# 1         5  6_6_6_sigmoid  {'error_increase_tolerance': 1e-05, 'exp_decay...
# 2         5  12_12_sigmoid  {'error_increase_tolerance': 1e-05, 'exp_decay...
# 3         5     12_sigmoid  {'error_increase_tolerance': 1e-05, 'exp_decay...
# 4         5     40_sigmoid  {'minibatch_size': 10, 'exp_decay_rate_2': 0.9...
#
#    mean_mean_euclidean_error  mean_mean_squared_error  \
# 0                   0.121779                 0.019921
# 1                   1.069022                 1.421318
# 2                   0.461650                 0.264049
# 3                   0.151632                 0.030697
# 4                   0.114844                 0.018009
#
#    var_mean_euclidean_error  var_mean_squared_error  \
# 0                  0.000109            1.121264e-05
# 1                  0.001646            1.684536e-02
# 2                  0.003136            3.735190e-03
# 3                  0.000015            5.139484e-07
# 4                  0.000007            1.969571e-06
#
#    mean_best_validation_training_error
# 0                             0.017031
# 1                             1.371320
# 2                             0.245064
# 3                             0.025322
# 4                             0.013112

# %%
columns_order = [x for x in columns_order if x in orig_df.columns]
orig_df = orig_df[columns_order]

order_by = 'mean_mean_euclidean_error'
orig_df.sort_values(by=[order_by], inplace=True)
orig_df = orig_df.reset_index(drop=True)
gs_results = orig_df.drop(['stats'], axis=1)

# %%
gs_results = gs_results.apply(remove_useless_val, axis=1)
for i in gs_results.columns[1:]:
    gs_results[i] = gs_results[i].astype(float)

# %%
numerical_col = list(gs_results.columns)
numerical_col.remove('topology')
st_opt_col = ['learning_rate','lr_decay_tau','alpha_momentum']
adamax_opt_col = ['adamax','adamax_learning_rate','exp_decay_rate_1','exp_decay_rate_2']
metrics_col = [x for x in gs_results.columns if x.startswith(('var', 'mean'))]
general_col = [item for item in list(gs_results.columns) if item not in st_opt_col and item not in metrics_col and item not in adamax_opt_col]
tr_input_col = [item for item in list(gs_results.columns) if item not in metrics_col]

# %%
error_treshold = 10
gs_results_clean = gs_results.loc[(gs_results['mean_mean_euclidean_error'].notna()) & (gs_results['mean_mean_euclidean_error'] < error_treshold)].copy()


gs_results_clean = gs_results_clean.reset_index(drop=True)
gs_results_clean.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bca2b_row0_col1, #T_bca2b_row0_col2, #T_bca2b_row0_col3, #T_bca2b_row0_col4, #T_bca2b_row0_col5, #T_bca2b_row0_col6, #T_bca2b_row0_col7, #T_bca2b_row0_col8, #T_bca2b_row0_col9, #T_bca2b_row0_col10, #T_bca2b_row0_col11, #T_bca2b_row0_col12, #T_bca2b_row0_col13, #T_bca2b_row0_col14, #T_bca2b_row0_col15, #T_bca2b_row1_col1, #T_bca2b_row1_col2, #T_bca2b_row1_col3, #T_bca2b_row1_col4, #T_bca2b_row1_col5, #T_bca2b_row1_col6, #T_bca2b_row1_col7, #T_bca2b_row1_col8, #T_bca2b_row1_col9, #T_bca2b_row1_col10, #T_bca2b_row1_col12, #T_bca2b_row1_col14, #T_bca2b_row1_col15, #T_bca2b_row2_col1, #T_bca2b_row2_col2, #T_bca2b_row2_col3, #T_bca2b_row2_col4, #T_bca2b_row2_col5, #T_bca2b_row2_col6, #T_bca2b_row2_col7, #T_bca2b_row2_col8, #T_bca2b_row2_col9, #T_bca2b_row2_col10, #T_bca2b_row2_col13, #T_bca2b_row2_col14, #T_bca2b_row3_col1, #T_bca2b_row3_col2, #T_bca2b_row3_col3, #T_bca2b_row3_col4, #T_bca2b_row3_col5, #T_bca2b_row3_col6, #T_bca2b_row3_col7, #T_bca2b_row3_col8, #T_bca2b_row3_col9, #T_bca2b_row3_col10, #T_bca2b_row4_col1, #T_bca2b_row4_col2, #T_bca2b_row4_col3, #T_bca2b_row4_col4, #T_bca2b_row4_col5, #T_bca2b_row4_col6, #T_bca2b_row4_col7, #T_bca2b_row4_col8, #T_bca2b_row4_col9, #T_bca2b_row4_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bca2b_row1_col11 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_bca2b_row1_col13 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_bca2b_row2_col11 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_bca2b_row2_col12, #T_bca2b_row2_col15 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_bca2b_row3_col11 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_bca2b_row3_col12 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_bca2b_row3_col13, #T_bca2b_row4_col11, #T_bca2b_row4_col12, #T_bca2b_row4_col14, #T_bca2b_row4_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bca2b_row3_col14 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_bca2b_row3_col15 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_bca2b_row4_col13 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bca2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bca2b_level0_col0" class="col_heading level0 col0" >topology</th>
#       <th id="T_bca2b_level0_col1" class="col_heading level0 col1" >batch_size</th>
#       <th id="T_bca2b_level0_col2" class="col_heading level0 col2" >min_epochs</th>
#       <th id="T_bca2b_level0_col3" class="col_heading level0 col3" >max_epochs</th>
#       <th id="T_bca2b_level0_col4" class="col_heading level0 col4" >patience</th>
#       <th id="T_bca2b_level0_col5" class="col_heading level0 col5" >error_increase_tolerance</th>
#       <th id="T_bca2b_level0_col6" class="col_heading level0 col6" >lambda_tikhonov</th>
#       <th id="T_bca2b_level0_col7" class="col_heading level0 col7" >learning_rate</th>
#       <th id="T_bca2b_level0_col8" class="col_heading level0 col8" >alpha_momentum</th>
#       <th id="T_bca2b_level0_col9" class="col_heading level0 col9" >lr_decay_tau</th>
#       <th id="T_bca2b_level0_col10" class="col_heading level0 col10" >adamax</th>
#       <th id="T_bca2b_level0_col11" class="col_heading level0 col11" >mean_mean_euclidean_error</th>
#       <th id="T_bca2b_level0_col12" class="col_heading level0 col12" >mean_mean_squared_error</th>
#       <th id="T_bca2b_level0_col13" class="col_heading level0 col13" >var_mean_euclidean_error</th>
#       <th id="T_bca2b_level0_col14" class="col_heading level0 col14" >var_mean_squared_error</th>
#       <th id="T_bca2b_level0_col15" class="col_heading level0 col15" >mean_best_validation_training_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bca2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bca2b_row0_col0" class="data row0 col0" >40_sigmoid</td>
#       <td id="T_bca2b_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_bca2b_row0_col2" class="data row0 col2" >100.000000</td>
#       <td id="T_bca2b_row0_col3" class="data row0 col3" >600.000000</td>
#       <td id="T_bca2b_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_bca2b_row0_col5" class="data row0 col5" >0.000010</td>
#       <td id="T_bca2b_row0_col6" class="data row0 col6" >0.000001</td>
#       <td id="T_bca2b_row0_col7" class="data row0 col7" >0.100000</td>
#       <td id="T_bca2b_row0_col8" class="data row0 col8" >0.900000</td>
#       <td id="T_bca2b_row0_col9" class="data row0 col9" >175.000000</td>
#       <td id="T_bca2b_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_bca2b_row0_col11" class="data row0 col11" >0.114844</td>
#       <td id="T_bca2b_row0_col12" class="data row0 col12" >0.018009</td>
#       <td id="T_bca2b_row0_col13" class="data row0 col13" >0.000007</td>
#       <td id="T_bca2b_row0_col14" class="data row0 col14" >0.000002</td>
#       <td id="T_bca2b_row0_col15" class="data row0 col15" >0.013112</td>
#     </tr>
#     <tr>
#       <th id="T_bca2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bca2b_row1_col0" class="data row1 col0" >20_sigmoid</td>
#       <td id="T_bca2b_row1_col1" class="data row1 col1" >10.000000</td>
#       <td id="T_bca2b_row1_col2" class="data row1 col2" >100.000000</td>
#       <td id="T_bca2b_row1_col3" class="data row1 col3" >600.000000</td>
#       <td id="T_bca2b_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_bca2b_row1_col5" class="data row1 col5" >0.000010</td>
#       <td id="T_bca2b_row1_col6" class="data row1 col6" >0.000001</td>
#       <td id="T_bca2b_row1_col7" class="data row1 col7" >0.100000</td>
#       <td id="T_bca2b_row1_col8" class="data row1 col8" >0.900000</td>
#       <td id="T_bca2b_row1_col9" class="data row1 col9" >175.000000</td>
#       <td id="T_bca2b_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_bca2b_row1_col11" class="data row1 col11" >0.121779</td>
#       <td id="T_bca2b_row1_col12" class="data row1 col12" >0.019921</td>
#       <td id="T_bca2b_row1_col13" class="data row1 col13" >0.000109</td>
#       <td id="T_bca2b_row1_col14" class="data row1 col14" >0.000011</td>
#       <td id="T_bca2b_row1_col15" class="data row1 col15" >0.017031</td>
#     </tr>
#     <tr>
#       <th id="T_bca2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bca2b_row2_col0" class="data row2 col0" >12_sigmoid</td>
#       <td id="T_bca2b_row2_col1" class="data row2 col1" >10.000000</td>
#       <td id="T_bca2b_row2_col2" class="data row2 col2" >100.000000</td>
#       <td id="T_bca2b_row2_col3" class="data row2 col3" >600.000000</td>
#       <td id="T_bca2b_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_bca2b_row2_col5" class="data row2 col5" >0.000010</td>
#       <td id="T_bca2b_row2_col6" class="data row2 col6" >0.000001</td>
#       <td id="T_bca2b_row2_col7" class="data row2 col7" >0.100000</td>
#       <td id="T_bca2b_row2_col8" class="data row2 col8" >0.900000</td>
#       <td id="T_bca2b_row2_col9" class="data row2 col9" >175.000000</td>
#       <td id="T_bca2b_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_bca2b_row2_col11" class="data row2 col11" >0.151632</td>
#       <td id="T_bca2b_row2_col12" class="data row2 col12" >0.030697</td>
#       <td id="T_bca2b_row2_col13" class="data row2 col13" >0.000015</td>
#       <td id="T_bca2b_row2_col14" class="data row2 col14" >0.000001</td>
#       <td id="T_bca2b_row2_col15" class="data row2 col15" >0.025322</td>
#     </tr>
#     <tr>
#       <th id="T_bca2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bca2b_row3_col0" class="data row3 col0" >12_12_sigmoid</td>
#       <td id="T_bca2b_row3_col1" class="data row3 col1" >10.000000</td>
#       <td id="T_bca2b_row3_col2" class="data row3 col2" >100.000000</td>
#       <td id="T_bca2b_row3_col3" class="data row3 col3" >600.000000</td>
#       <td id="T_bca2b_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_bca2b_row3_col5" class="data row3 col5" >0.000010</td>
#       <td id="T_bca2b_row3_col6" class="data
