# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import pandas as pd
import plotly.express as px
import random
import json
from sklearn.preprocessing import MinMaxScaler

sys.path.append(os.path.abspath('../src/'))
from ModelSelection import *
from ActivationFunctions import *
from NeuralNetwork import *
from MyUtils import *

# %%
tr_df = pd.read_csv('../data/monks_csv/monks_tr_2.csv', index_col=0)
len_training = len(tr_df)
val_df = pd.read_csv('../data/monks_csv/monks_ts_2.csv', index_col=0) # test in realtà ma va be
len_validation = len(val_df)
len_dataset = len_training + len_validation
val_df.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  output_1
# 173        2        1        2        1        3        2         1
# 91         1        2        2        3        2        2         0
# 105        1        3        1        2        1        2         0
# 431        3        3        2        3        4        2         0
# 389        3        3        1        1        3        2         1

# %%
def OHE(df):
    OHE = pd.get_dummies(df, columns=['input_'+str(i) for i in range(1, 7)])
    OHE = OHE.set_axis(['output_1'] + ['input_' + str(i) for i in range(1, len(OHE.columns))], axis=1)
    cols = OHE.columns.tolist()
    cols = cols[1:] + cols[:1]
    OHE = OHE[cols]
    return OHE

# %%
tr_df_OHE = OHE(tr_df)
tr_df_OHE.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  input_7  input_8  \
# 109    False     True    False    False    False     True    False     True
# 59     False     True    False     True    False    False     True    False
# 51      True    False    False    False    False     True    False     True
# 56      True    False    False    False    False     True    False     True
# 35      True    False    False    False     True    False    False     True
#
#      input_9  input_10  input_11  input_12  input_13  input_14  input_15  \
# 109    False      True     False     False      True     False     False
# 59      True     False     False     False     False      True     False
# 51      True     False     False     False     False      True     False
# 56     False     False      True     False      True     False     False
# 35     False     False      True     False     False      True     False
#
#      input_16  input_17  output_1
# 109      True     False         0
# 59       True     False         0
# 51      False      True         1
# 56       True     False         1
# 35       True     False         1

# %%
val_df_OHE = OHE(val_df)
val_df_OHE.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  input_7  input_8  \
# 173    False     True    False     True    False    False    False     True
# 91      True    False    False    False     True    False    False     True
# 105     True    False    False    False    False     True     True    False
# 431    False    False     True    False    False     True    False     True
# 389    False    False     True    False    False     True     True    False
#
#      input_9  input_10  input_11  input_12  input_13  input_14  input_15  \
# 173     True     False     False     False     False      True     False
# 91     False     False      True     False      True     False     False
# 105    False      True     False      True     False     False     False
# 431    False     False      True     False     False     False      True
# 389     True     False     False     False     False      True     False
#
#      input_16  input_17  output_1
# 173     False      True         1
# 91      False      True         0
# 105     False      True         0
# 431     False      True         0
# 389     False      True         1

# %% [markdown]
# From monk database:
#
# Attribute information:
# 1. class: 0, 1
# 2. a1:    1, 2, 3
# 3. a2:    1, 2, 3
# 4. a3:    1, 2
# 5. a4:    1, 2, 3
# 6. a5:    1, 2, 3, 4
# 7. a6:    1, 2
# 8. Id:    (A unique symbol for each instance)

# %%
TR_INPUT = len(tr_df_OHE.columns) - 1
TR_OUTPUT = 1
hidden_len = 4
topology = create_stratified_topology([TR_INPUT,hidden_len,TR_OUTPUT], 
                                      [[None,[]]]*TR_INPUT + [['sigmoid', [1]]]*hidden_len + [['sigmoid', [1]]])
NeuralNetwork.display_topology(topology)

# %%
MS = ModelSelection('../data/gs_data/monk_2_kf.csv')
training_set = tr_df_OHE.values
hyperparam_grid = {
    'learning_rate':[0.1,0.2,0.4,0.6],
    'alpha_momentum':[0.3,0.5,0.7],
    'lambda_tikhonov':[0],
    'batch_size':[int(len(training_set)/15)], # minibatch, online, batch
    'min_epochs': [80],
    'max_epochs':[400, 600],
    'error_increase_tolerance':[np.inf],
    'patience':[50],
    'topology': [str(topology)],
}

MS.grid_searchKF(training_set, hyperparam_grid,{}, 5, 4, False)
# Out:
# tot conf: 24

# %%
df = pd.read_csv('../data/gs_data/monk_2_kf.csv')

df.sample(3, random_state=RANDOM_STATE)

df['mean_metrics'] = df['mean_metrics'].apply(lambda x: ast.literal_eval(x))

df = df.sort_values(by=['mean_metrics'], ascending=True)

# %%
df.drop(['stats', 'topology'], axis=1).head(10)
# Out:
#     alpha_momentum  batch_size  error_increase_tolerance  lambda_tikhonov  \
# 0              0.5          11                       inf                0
# 18             0.3          11                       inf                0
# 12             0.7          11                       inf                0
# 20             0.7          11                       inf                0
# 22             0.7          11                       inf                0
# 14             0.7          11                       inf                0
# 10             0.5          11                       inf                0
# 17             0.7          11                       inf                0
# 6              0.3          11                       inf                0
# 21             0.7          11                       inf                0
#
#     learning_rate  max_epochs  min_epochs  patience           metrics_names  \
# 0             0.6         400          80        50  ['mean_squared_error']
# 18            0.4         600          80        50  ['mean_squared_error']
# 12            0.4         400          80        50  ['mean_squared_error']
# 20            0.6         600          80        50  ['mean_squared_error']
# 22            0.6         400          80        50  ['mean_squared_error']
# 14            0.2         600          80        50  ['mean_squared_error']
# 10            0.6         600          80        50  ['mean_squared_error']
# 17            0.2         400          80        50  ['mean_squared_error']
# 6             0.2         400          80        50  ['mean_squared_error']
# 21            0.4         600          80        50  ['mean_squared_error']
#
#              mean_metrics         variance_metrics  \
# 0   [0.16236254818124182]   [0.018697902411011456]
# 18    [0.165466794863484]   [0.017979318895887268]
# 12  [0.18369860868574056]   [0.013735788623342727]
# 20   [0.1982755805629794]    [0.01944481390086231]
# 22  [0.20041947398395937]   [0.013536739583694123]
# 14  [0.20155845753476337]   [0.011746619488835828]
# 10  [0.21192834518278963]   [0.013005437729699662]
# 17   [0.2271083902635048]  [0.0014817292081764845]
# 6   [0.23933841110039594]  [0.0019167641945299807]
# 21  [0.23942522883073097]   [0.004182690727443679]
#
#     mean_best_validation_training_error
# 0                                   inf
# 18                                  inf
# 12                                  inf
# 20                                  inf
# 22                                  inf
# 14                                  inf
# 10                                  inf
# 17                                  inf
# 6                                   inf
# 21                                  inf

# %%
training_set = tr_df_OHE.values
validation_set = val_df_OHE.values
metrics = [ErrorFunctions.mean_squared_error, ] #ErrorFunctions.mean_euclidean_error, 

batch_size = int(len(training_set)/15)
max_epochs = 400

error_increase_tolerance = np.inf
patience = 50
min_epochs = 80

lambda_tikhonov = 0
alpha_momentum = 0.3
learning_rate = 0.4/batch_size
# beacause of the momentum is used the learning rate needs to be a little less?!?!?

collect_datas = True
collect_datas_batch = False # per il momento. molto costoso!!!! False di default
verbose = True

NN = NeuralNetwork(topology, -0.75, 0.75, True, RANDOM_STATE)
stats = NN.train(training_set, validation_set, 
                 batch_size = batch_size, 
                 max_epochs = max_epochs, 
                 error_increase_tolerance = error_increase_tolerance, 
                 patience = patience, 
                 min_epochs = min_epochs, 
                 lambda_tikhonov = lambda_tikhonov, 
                 metrics = metrics, 
                 
                 learning_rate=learning_rate,
                 alpha_momentum=alpha_momentum,
                 lr_decay_tau=0,
                 eta_tau=0,
                 
                 collect_data=True,
                 collect_data_batch=False,
                 verbose=True)
# Out:
# starting values:  {'training_set_len': 169, 'minibatch_size': 11, 'max_epochs': 400, 'retraing_es_error': -1, 'error_increase_tolerance': inf, 'patience': 50, 'min_epochs': 80, 'learning_rate': 0.03636363636363637, 'lr_decay_tau': 0, 'eta_tau': 0, 'lambda_tikhonov': 0, 'alpha_momentum': 0.3, 'nesterov': False, 'adamax': False, 'adamax_learning_rate': 0.01, 'exp_decay_rates_1': 0.9, 'exp_decay_rates_2': 0.999, 'best_validation_training_error': inf, 'epochs': 0, 'total_train_time': datetime.timedelta(days=-1, seconds=86399, microseconds=999995), 'mean_epoch_train_time': 0, 'units_weights': {20: [], 19: [], 18: [], 17: [], 21: []}, 'units_weights_batch': {20: [], 19: [], 18: [], 17: [], 21: []}, 'training_mean_squared_error': [], 'validation_mean_squared_error': [], 'training_batch_mean_squared_error': [], 'validation_batch_mean_squared_error': []}
# [1/400] tr time: 0:00:00.103735 | mean_squared_error: tr=0.24346656688340695 val=0.24006624493225945 |
# [2/400] tr time: 0:00:00.073626 | mean_squared_error: tr=0.23641262601238847 val=0.22731836952343973 |
# [3/400] tr time: 0:00:00.046261 | mean_squared_error: tr=0.23520881016309736 val=0.2225304634248019 |
# [4/400] tr time: 0:00:00.050982 | mean_squared_error: tr=0.23525210069133468 val=0.2229314374845136 |
# [5/400] tr time: 0:00:00.067576 | mean_squared_error: tr=0.2352766589808316 val=0.22392973133533436 |
# [6/400] tr time: 0:00:00.072204 | mean_squared_error: tr=0.2351336342934091 val=0.22213656072401677 |
# [7/400] tr time: 0:00:00.045275 | mean_squared_error: tr=0.2351695193311473 val=0.2227985246988691 |
# [8/400] tr time: 0:00:00.055139 | mean_squared_error: tr=0.2352141739503992 val=0.22357552944506842 |
# [9/400] tr time: 0:00:00.047010 | mean_squared_error: tr=0.2352213978044261 val=0.22201992251019453 |
# [10/400] tr time: 0:00:00.044625 | mean_squared_error: tr=0.23525449294618797 val=0.22292742625436748 |
# [11/400] tr time: 0:00:00.045156 | mean_squared_error: tr=0.2354555195412689 val=0.2242911188669579 |
# [12/400] tr time: 0:00:00.053135 | mean_squared_error: tr=0.23526725401309123 val=0.22203241548923777 |
# [13/400] tr time: 0:00:00.046021 | mean_squared_error: tr=0.23526474398012726 val=0.2229973212374253 |
# [14/400] tr time: 0:00:00.049836 | mean_squared_error: tr=0.2352795882686001 val=0.22150352227354786 |
# [72/400] tr time: 0:00:00.045553 | mean_squared_error: tr=0.22664070155672678 val=0.21573297572460984 |
# [73/400] tr time: 0:00:00.047767 | mean_squared_error: tr=0.22629528290710493 val=0.21595744976509115 |
# [74/400] tr time: 0:00:00.043110 | mean_squared_error: tr=0.22587657436979572 val=0.21607346406866063 |
# [75/400] tr time: 0:00:00.045654 | mean_squared_error: tr=0.22570591044224386 val=0.21509812159894737 |
# [76/400] tr time: 0:00:00.044109 | mean_squared_error: tr=0.22544700330815665 val=0.21537009764614262 |
# [77/400] tr time: 0:00:00.044422 | mean_squared_error: tr=0.2249189313307406 val=0.21573600386263833 |
# [78/400] tr time: 0:00:00.046793 | mean_squared_error: tr=0.22490041808261138 val=0.2146190783218975 |
# [79/400] tr time: 0:00:00.042697 | mean_squared_error: tr=0.2244356251266718 val=0.21490483820196205 |
# [80/400] tr time: 0:00:00.047396 | mean_squared_error: tr=0.22456405669987906 val=0.21408666453345215 |
# [81/400] tr time: 0:00:00.045293 | mean_squared_error: tr=0.22435253119819892 val=0.21439260781189892 |
# [82/400] tr time: 0:00:00.043172 | mean_squared_error: tr=0.22369082719735092 val=0.21471945486972516 |
# [83/400] tr time: 0:00:00.045949 | mean_squared_error: tr=0.22350012009111514 val=0.21370667889536787 |
# [84/400] tr time: 0:00:00.043783 | mean_squared_error: tr=0.2231639168621205 val=0.213873320027165 |
# [85/400] tr time: 0:00:00.046279 | mean_squared_error: tr=0.22265242160043885 val=0.21393014772280064 |
# [86/400] tr time: 0:00:00.045287 | mean_squared_error: tr=0.22259074132395407 val=0.213036087814667 |
# [87/400] tr time: 0:00:00.043820 | mean_squared_error: tr=0.22234935999329616 val=0.21331021253290552 |
# [88/400] tr time: 0:00:00.044399 | mean_squared_error: tr=0.22175221617631385 val=0.21374340910645875 |
# [89/400] tr time: 0:00:00.046098 | mean_squared_error: tr=0.22190568186866513 val=0.21263063770489207 |
# [90/400] tr time: 0:00:00.042817 | mean_squared_error: tr=0.22142941864644147 val=0.21292601039079248 |
# [91/400] tr time: 0:00:00.046560 | mean_squared_error: tr=0.22163526341222467 val=0.21223806696495431 |
# [92/400] tr time: 0:00:00.045065 | mean_squared_error: tr=0.2215067292168327 val=0.21253525211767912 |
# [93/400] tr time: 0:00:00.046220 | mean_squared_error: tr=0.2207352684236986 val=0.21284758282485608 |
# [94/400] tr time: 0:00:00.046903 | mean_squared_error: tr=0.22063290974596428 val=0.21192933880763382 |
# [95/400] tr time: 0:00:00.043992 | mean_squared_error: tr=0.22037669904415472 val=0.21205205003090524 |
# [96/400] tr time: 0:00:00.045762 | mean_squared_error: tr=0.21980176754736605 val=0.21207600935682155 |
# [97/400] tr time: 0:00:00.049979 | mean_squared_error: tr=0.21991176509609528 val=0.21131762140936822 |
# [98/400] tr time: 0:00:00.044590 | mean_squared_error: tr=0.2197293953057492 val=0.21162547516827135 |
# [99/400] tr time: 0:00:00.045715 | mean_squared_error: tr=0.21910656940314707 val=0.2121763072140437 |
# [100/400] tr time: 0:00:00.047287 | mean_squared_error: tr=0.21947572601036758 val=0.21107971994625951 |
# [159/400] tr time: 0:00:00.043398 | mean_squared_error: tr=0.21151134569714886 val=0.20800076003027165 |
# [160/400] tr time: 0:00:00.046002 | mean_squared_error: tr=0.21138212190671102 val=0.20717113962639785 |
# [161/400] tr time: 0:00:00.045811 | mean_squared_error: tr=0.21125986820655898 val=0.20705217781544746 |
# [162/400] tr time: 0:00:00.045044 | mean_squared_error: tr=0.21043303407512814 val=0.20692110241932707 |
# [163/400] tr time: 0:00:00.044647 | mean_squared_error: tr=0.21064318544271754 val=0.20616191721247912 |
# [164/400] tr time: 0:00:00.044104 | mean_squared_error: tr=0.21059606155734306 val=0.20667968228949127 |
# [165/400] tr time: 0:00:00.043288 | mean_squared_error: tr=0.21018640011560635 val=0.20760705293068704 |
# [166/400] tr time: 0:00:00.046296 | mean_squared_error: tr=0.21035627610642502 val=0.20592832344220668 |
# [167/400] tr time: 0:00:00.044044 | mean_squared_error: tr=0.20988925267037126 val=0.20623417123141602 |
# [168/400] tr time: 0:00:00.044197 | mean_squared_error: tr=0.20976527170065265 val=0.20563879308868646 |
# [169/400] tr time: 0:00:00.045063 | mean_squared_error: tr=0.20999406344333865 val=0.205994002561223 |
# [170/400] tr time: 0:00:00.052555 | mean_squared_error: tr=0.20910331213756506 val=0.20636093202597203 |
# [171/400] tr time: 0:00:00.046559 | mean_squared_error: tr=0.20880666019553415 val=0.2053372330747372 |
# [172/400] tr time: 0:00:00.048002 | mean_squared_error: tr=0.2085768190883315 val=0.20513086950685724 |
# [173/400] tr time: 0:00:00.041831 | mean_squared_error: tr=0.20764714815378266 val=0.20492011939810256 |
# [174/400] tr time: 0:00:00.053643 | mean_squared_error: tr=0.20767118780149202 val=0.20394877658652533 |
# [175/400] tr time: 0:00:00.045147 | mean_squared_error: tr=0.20755321689243234 val=0.20448187804588455 |
# [176/400] tr time: 0:00:00.044116 | mean_squared_error: tr=0.20715521292916148 val=0.2053980131107574 |
# [177/400] tr time: 0:00:00.045158 | mean_squared_error: tr=0.20700572315139826 val=0.20339907818006042 |
# [178/400] tr time: 0:00:00.044404 | mean_squared_error: tr=0.20643795434324455 val=0.20363757064652116 |
# [179/400] tr time: 0:00:00.047812 | mean_squared_error: tr=0.20611850141298171 val=0.2029447009714607 |
# [180/400] tr time: 0:00:00.043159 | mean_squared_error: tr=0.20623894994662115 val=0.20320761936942452 |
# [181/400] tr time: 0:00:00.043357 | mean_squared_error: tr=0.2052944402635895 val=0.20352835825524396 |
# [182/400] tr time: 0:00:00.044902 | mean_squared_error: tr=0.20475574510799538 val=0.2022278288480577 |
# [183/400] tr time: 0:00:00.044324 | mean_squared_error: tr=0.20434969593340024 val=0.20187496643918787 |
# [184/400] tr time: 0:00:00.042648 | mean_squared_error: tr=0.2032944501015953 val=0.20156344365013318 |
# [185/400] tr time: 0:00:00.047030 | mean_squared_error: tr=0.20307449744978837 val=0.20030547781776598 |
# [186/400] tr time: 0:00:00.045214 | mean_squared_error: tr=0.20281908236196033 val=0.20083410873874233 |
# [187/400] tr time: 0:00:00.044755 | mean_squared_error: tr=0.2024025798507011 val=0.20172877974138956 |
# [188/400] tr time: 0:00:00.046944 | mean_squared_error: tr=0.20185807877475753 val=0.19929037413700007 |
# [189/400] tr time: 0:00:00.043415 | mean_squared_error: tr=0.2011576948071197 val=0.19945342534065102 |
# [190/400] tr time: 0:00:00.049256 | mean_squared_error: tr=0.20062975321250875 val=0.1986651159608997 |
# [191/400] tr time: 0:00:00.044679 | mean_squared_error: tr=0.20056746788522195 val=0.19873191992465344 |
# [192/400] tr time: 0:00:00.043136 | mean_squared_error: tr=0.19951876040917912 val=0.19897356236047034 |
# [193/400] tr time: 0:00:00.045964 | mean_squared_error: tr=0.19868234355288972 val=0.19732833249030862 |
# [194/400] tr time: 0:00:00.044412 | mean_squared_error: tr=0.19803509645608638 val=0.19675014005437805 |
# [195/400] tr time: 0:00:00.045495 | mean_squared_error: tr=0.1968771282981539 val=0.19636608099876104 |
# [196/400] tr time: 0:00:00.044758 | mean_squared_error: tr=0.1963846052142291 val=0.19474478847297855 |
# [197/400] tr time: 0:00:00.043368 | mean_squared_error: tr=0.19591931535543217 val=0.19524809795815 |
# [198/400] tr time: 0:00:00.043578 | mean_squared_error: tr=0.19545990747003483 val=0.1961449753929631 |
# [199/400] tr time: 0:00:00.048390 | mean_squared_error: tr=0.1944873928032718 val=0.19312723560658132 |
# [200/400] tr time: 0:00:00.043231 | mean_squared_error: tr=0.1936454698419567 val=0.19323942778824302 |
# [201/400] tr time: 0:00:00.044330 | mean_squared_error: tr=0.19288676455938755 val=0.1923188357934342 |
# [202/400] tr time: 0:00:00.043876 | mean_squared_error: tr=0.19257261920511015 val=0.19206939923303887 |
# [203/400] tr time: 0:00:00.044391 | mean_squared_error: tr=0.19137695857246778 val=0.19223684406728878 |
# [204/400] tr time: 0:00:00.045130 | mean_squared_error: tr=0.19020486605185116 val=0.1901932874255223 |
# [205/400] tr time: 0:00:00.043308 | mean_squared_error: tr=0.18928108121816828 val=0.18932001572694335 |
# [206/400] tr time: 0:00:00.045079 | mean_squared_error: tr=0.18809749041732554 val=0.1889620051809118 |
# [207/400] tr time: 0:00:00.047880 | mean_squared_error: tr=0.18731090019370134 val=0.18689080068444425 |
# [208/400] tr time: 0:00:00.042954 | mean_squared_error: tr=0.18659866169599826 val=0.1873792112913091 |
# [209/400] tr time: 0:00:00.042628 | mean_squared_error: tr=0.18614970935795994 val=0.18837484933809379 |
# [210/400] tr time: 0:00:00.045543 | mean_squared_error: tr=0.18467802920976262 val=0.18459279253639696 |
# [211/400] tr time: 0:00:00.045257 | mean_squared_error: tr=0.18374679903074972 val=0.18475324345189173 |
# [212/400] tr time: 0:00:00.044635 | mean_squared_error: tr=0.1826715615839963 val=0.18357368514756456 |
# [213/400] tr time: 0:00:00.043580 | mean_squared_error: tr=0.1820193107093889 val=0.18290160401866024 |
# [214/400] tr time: 0:00:00.044053 | mean_squared_error: tr=0.18077043393961767 val=0.18313331695654403 |
# [215/400] tr time: 0:00:00.048885 | mean_squared_error: tr=0.17927069994766903 val=0.18067374659617835 |
# [303/400] tr time: 0:00:00.046127 | mean_squared_error: tr=0.07612598372569386 val=0.08533498454509891 |
# [304/400] tr time: 0:00:00.046233 | mean_squared_error: tr=0.07399641157782927 val=0.08222260262328641 |
# [305/400] tr time: 0:00:00.044730 | mean_squared_error: tr=0.07520986098400231 val=0.084634836523783 |
# [306/400] tr time: 0:00:00.045426 | mean_squared_error: tr=0.07037807939452405 val=0.07849383012538794 |
# [307/400] tr time: 0:00:00.042648 | mean_squared_error: tr=0.07162017933638527 val=0.08092963156712603 |
# [308/400] tr time: 0:00:00.043139 | mean_squared_error: tr=0.07332658334972303 val=0.08341420353393435 |
# [309/400] tr time: 0:00:00.050188 | mean_squared_error: tr=0.06574108879201407 val=0.07344980388215785 |
# [310/400] tr time: 0:00:00.042186 | mean_squared_error: tr=0.0680160854374128 val=0.07683501599623871 |
# [311/400] tr time: 0:00:00.045375 | mean_squared_error: tr=0.06503105054028623 val=0.07397400660712573 |
# [312/400] tr time: 0:00:00.042961 | mean_squared_error: tr=0.06347220094052237 val=0.07227368144684167 |
# [313/400] tr time: 0:00:00.045463 | mean_squared_error: tr=0.06411753947702437 val=0.07314618283998699 |
# [314/400] tr time: 0:00:00.044862 | mean_squared_error: tr=0.06156275001825504 val=0.07014337506636434 |
# [315/400] tr time: 0:00:00.042543 | mean_squared_error: tr=0.05919089301628562 val=0.0666161945293158 |
# [316/400] tr time: 0:00:00.041811 | mean_squared_error: tr=0.06039870416865996 val=0.06914246060428104 |
# [317/400] tr time: 0:00:00.049053 | mean_squared_error: tr=0.055829409732664835 val=0.06344784282377885 |
# [318/400] tr time: 0:00:00.042338 | mean_squared_error: tr=0.05635423657120928 val=0.06489951437068851 |
# [319/400] tr time: 0:00:00.041509 | mean_squared_error: tr=0.057798012652493444 val=0.0672253174744147 |
# [320/400] tr time: 0:00:00.046051 | mean_squared_error: tr=0.05102775701311108 val=0.0582633463593932 |
# [321/400] tr time: 0:00:00.043159 | mean_squared_error: tr=0.052869213058245726 val=0.06104284249591066 |
# [322/400] tr time: 0:00:00.047984 | mean_squared_error: tr=0.05007043612513212 val=0.05840737305666698 |
# [323/400] tr time: 0:00:00.043036 | mean_squared_error: tr=0.04881935157332659 val=0.05716166327329942 |
# [324/400] tr time: 0:00:00.043107 | mean_squared_error: tr=0.04923127748992648 val=0.05765655039555189 |
# [325/400] tr time: 0:00:00.044510 | mean_squared_error: tr=0.04721510602899272 val=0.05536110645147077 |
# [326/400] tr time: 0:00:00.045871 | mean_squared_error: tr=0.044693732019002716 val=0.051556053681880834 |
# [327/400] tr time: 0:00:00.042302 | mean_squared_error: tr=0.04601007556358989 val=0.05423525393186606 |
# [328/400] tr time: 0:00:00.045157 | mean_squared_error: tr=0.042367095347812356 val=0.04952660483240522 |
# [329/400] tr time: 0:00:00.044580 | mean_squared_error: tr=0.042337867994030935 val=0.05012769951003156 |
# [330/400] tr time: 0:00:00.044592 | mean_squared_error: tr=0.043763893037358476 val=0.052512605954491684 |
# [331/400] tr time: 0:00:00.046230 | mean_squared_error: tr=0.038520021367537564 val=0.0451653336919239 |
# [389/400] tr time: 0:00:00.043524 | mean_squared_error: tr=0.01395924270836152 val=0.01697252802956397 |
# [390/400] tr time: 0:00:00.045230 | mean_squared_error: tr=0.014084558198089743 val=0.017320375948219384 |
# [391/400] tr time: 0:00:00.045445 | mean_squared_error: tr=0.013852441322665615 val=0.01698386761082406 |
# [392/400] tr time: 0:00:00.042649 | mean_squared_error: tr=0.013320504698182465 val=0.01603375636346109 |
# [393/400] tr time: 0:00:00.045071 | mean_squared_error: tr=0.013480263663436078 val=0.0165013907297451 |
# [394/400] tr time: 0:00:00.047261 | mean_squared_error: tr=0.012957794339575026 val=0.01563016062923012 |
# [395/400] tr time: 0:00:00.046010 | mean_squared_error: tr=0.012986360160681186 val=0.015817440440000014 |
# [396/400] tr time: 0:00:00.044162 | mean_squared_error: tr=0.01326289810888707 val=0.016406680362635966 |
# [397/400] tr time: 0:00:00.046320 | mean_squared_error: tr=0.012417348400331199 val=0.014884709575156507 |
# [398/400] tr time: 0:00:00.045047 | mean_squared_error: tr=0.012622184565548542 val=0.015377910634555993 |
# [399/400] tr time: 0:00:00.044634 | mean_squared_error: tr=0.012223595699723117 val=0.014784945439089967 |
# [400/400] tr time: 0:00:00.044510 | mean_squared_error: tr=0.012172341657949346 val=0.014759140557638049 |

# %%
tr_predictions = NN.predict_array(training_set[:,:TR_INPUT])
val_predictions = NN.predict_array(validation_set[:,:TR_INPUT])

# %%
pd.options.mode.chained_assignment = None
prediction_col = ['prediction_1']#, 'prediction_2', 'prediction_3']
for col in prediction_col:
    tr_df[prediction_col] = np.array([[1] if x > 0.5 else [0] for x in tr_predictions])
    tr_df[col + '_err'] = (tr_df[col] - tr_df['output_' + col[-1]])**2

# %%
tr_df['prediction_1_err'].max()
# Out:
# 0

# %%
tr_df.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  output_1  \
# 109        2        3        2        2        2        1         0
# 59         2        1        1        1        3        1         0
# 51         1        3        2        1        3        2         1
# 56         1        3        2        3        2        1         1
# 35         1        2        2        3        3        1         1
#
#      prediction_1  prediction_1_err
# 109             0                 0
# 59              0                 0
# 51              1                 0
# 56              1                 0
# 35              1                 0

# %%
val_df[prediction_col] = val_predictions
for col in prediction_col:
    val_df[prediction_col] = np.array([[1] if x > 0.5 else [0] for x in val_predictions])
    val_df[col + '_err'] = (val_df[col] - val_df['output_' + col[-1]])**2

# %%
val_df.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  output_1  \
# 173        2        1        2        1        3        2         1
# 91         1        2        2        3        2        2         0
# 105        1        3        1        2        1        2         0
# 431        3        3        2        3        4        2         0
# 389        3        3        1        1        3        2         1
#
#      prediction_1  prediction_1_err
# 173             1                 0
# 91              0                 0
# 105             0                 0
# 431             0                 0
# 389             1                 0

# %%
print('training accuracy =', (tr_df['output_1'] == tr_df['prediction_1']).sum() / len(tr_df))
print('validation accuracy =', (val_df['output_1'] == val_df['prediction_1']).sum() / len(val_df))
# Out:
# training accuracy = 1.0
# validation accuracy = 1.0

# %%
print('misclassified =', (tr_df['output_1'] != tr_df['prediction_1']).sum(), 'su', len(tr_df))
print('misclassified =', (val_df['output_1'] != val_df['prediction_1']).sum(), 'su', len(val_df))
# Out:
# misclassified = 0 su 169
# misclassified = 0 su 432

# %%
for key in list(stats.keys())[:12]:
    print(key, ':', stats[key])
# Out:
# training_set_len : 169
# minibatch_size : 11
# max_epochs : 400
# retraing_es_error : -1
# error_increase_tolerance : inf
# patience : 50
# min_epochs : 80
# learning_rate : 0.03636363636363637
# lr_decay_tau : 0
# eta_tau : 0
# lambda_tikhonov : 0
# alpha_momentum : 0.3

# %%
for met in metrics:
    print('last training ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
    print('last validation ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
# Out:
# last training mean_squared_error : 0.012172341657949346
# last validation mean_squared_error : 0.012172341657949346

# %%
for met in metrics:
    print('last training ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
    print('last validation ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
# Out:
# last training mean_squared_error : 0.012172341657949346
# last validation mean_squared_error : 0.012172341657949346

# %%
if len(metrics) > 1:
    fig, ax = plt.subplots(1, len(metrics), figsize=(10, 5))
    plt.suptitle('Training Metrics (epochs)')
    for i in range(len(metrics)):
        multy_plot([stats['training_' + metrics[i].__name__], stats['validation_' + metrics[i].__name__]], 
                ['training_' + metrics[i].__name__, 'validation_' + metrics[i].__name__],
                ax=ax[i])
else:
    plt.suptitle('Training Metrics (epochs)')
    multy_plot([stats['training_' + metrics[0].__name__], stats['validation_' + metrics[0].__name__]], 
                ['training_' + metrics[0].__name__, 'validation_' + metrics[0].__name__])

# %%
if len(metrics) > 1:
    fig, ax = plt.subplots(1, len(metrics), figsize=(10, 5))
    plt.suptitle('Learning Curve (batch)')
    for i in range(len(metrics)):
        multy_plot([stats['training_batch_' + metrics[i].__name__], stats['validation_batch_' + metrics[i].__name__]], 
                ['training_batch_' + metrics[i].__name__, 'validation_batch_' + metrics[i].__name__],
                ax=ax[i])
    plt.show()
else:
    plt.suptitle('Training Metrics (batch)')
    multy_plot([stats['training_batch_' + metrics[0].__name__], stats['validation_batch_' + metrics[0].__name__]], 
                ['training_batch_' + metrics[0].__name__, 'validation_batch_' + metrics[0].__name__])

# %%
for unit_index in stats['units_weights'].keys():
    vals = np.array(stats['units_weights'][unit_index]).T
    multy_plot(vals, 
               ['weight_' + str(i) for i in range(len(vals))], 
               'Unit ' + str(unit_index) + ' Weights (unit type: ' + NN.neurons[unit_index].type + ')')

# %%
for i in range(TR_OUTPUT):
    sorted_order = training_set[:, TR_INPUT + i].argsort()
    multy_plot([tr_df['prediction_1'].values[sorted_order] , tr_df['output_1'].values[sorted_order]], 
                ['output_val', 'target_val'], 
                'NN Output_' + str(i + 1) +  ' Values')

# %%
for i in range(TR_OUTPUT):
    sorted_order = validation_set[:, TR_INPUT + i].argsort()
    multy_plot([val_df['prediction_1'].values[sorted_order] , val_df['output_1'].values[sorted_order]], 
                ['output_val', 'target_val'], 
                'NN Output_' + str(i + 1) +  ' Values')
