# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import pandas as pd
import plotly.express as px
import random
import json
from sklearn.preprocessing import MinMaxScaler

sys.path.append(os.path.abspath('../src/'))
from ModelSelection import *
from ActivationFunctions import *
from NeuralNetwork import *
from MyUtils import *

# %%
tr_df = pd.read_csv('../data/monks_csv/monks_tr_3.csv', index_col=0)
len_training = len(tr_df)
val_df = pd.read_csv('../data/monks_csv/monks_ts_3.csv', index_col=0) # test in realtà ma va be
len_validation = len(val_df)
len_dataset = len_training + len_validation
val_df.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  output_1
# 173        2        1        2        1        3        2         1
# 91         1        2        2        3        2        2         1
# 105        1        3        1        2        1        2         0
# 431        3        3        2        3        4        2         0
# 389        3        3        1        1        3        2         1

# %%
def OHE(df):
    OHE = pd.get_dummies(df, columns=['input_'+str(i) for i in range(1, 7)])
    OHE = OHE.set_axis(['output_1'] + ['input_' + str(i) for i in range(1, len(OHE.columns))], axis=1)
    cols = OHE.columns.tolist()
    cols = cols[1:] + cols[:1]
    OHE = OHE[cols]
    return OHE

# %%
tr_df_OHE = OHE(tr_df)
tr_df_OHE.sample(5, random_state=RANDOM_STATE)
# Out:
#     input_1  input_2  input_3  input_4  input_5  input_6  input_7  input_8  \
# 93    False    False     True     True    False    False     True    False
# 16     True    False    False     True    False    False    False     True
# 17     True    False    False    False     True    False     True    False
# 95    False    False     True     True    False    False    False     True
# 35     True    False    False    False    False     True     True    False
#
#     input_9  input_10  input_11  input_12  input_13  input_14  input_15  \
# 93    False     False      True     False     False     False      True
# 16    False     False      True     False     False      True     False
# 17     True     False     False     False     False      True     False
# 95    False      True     False     False     False      True     False
# 35     True     False     False     False      True     False     False
#
#     input_16  input_17  output_1
# 93     False      True         0
# 16     False      True         1
# 17      True     False         1
# 95     False      True         1
# 35      True     False         0

# %%
val_df_OHE = OHE(val_df)
val_df_OHE.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  input_7  input_8  \
# 173    False     True    False     True    False    False    False     True
# 91      True    False    False    False     True    False    False     True
# 105     True    False    False    False    False     True     True    False
# 431    False    False     True    False    False     True    False     True
# 389    False    False     True    False    False     True     True    False
#
#      input_9  input_10  input_11  input_12  input_13  input_14  input_15  \
# 173     True     False     False     False     False      True     False
# 91     False     False      True     False      True     False     False
# 105    False      True     False      True     False     False     False
# 431    False     False      True     False     False     False      True
# 389     True     False     False     False     False      True     False
#
#      input_16  input_17  output_1
# 173     False      True         1
# 91      False      True         1
# 105     False      True         0
# 431     False      True         0
# 389     False      True         1

# %% [markdown]
# From monk database:
#
# Attribute information:
# 1. class: 0, 1
# 2. a1:    1, 2, 3
# 3. a2:    1, 2, 3
# 4. a3:    1, 2
# 5. a4:    1, 2, 3
# 6. a5:    1, 2, 3, 4
# 7. a6:    1, 2
# 8. Id:    (A unique symbol for each instance)

# %%
TR_INPUT = len(tr_df_OHE.columns) - 1
TR_OUTPUT = 1
hidden_len = 4
topology = create_stratified_topology([TR_INPUT,hidden_len,TR_OUTPUT], 
                                      [[None,[]]]*TR_INPUT + [['sigmoid', [1]]]*hidden_len + [['sigmoid', [1]]])
NeuralNetwork.display_topology(topology)

# %%
df = pd.read_csv('../data/gs_data/monk_3_selection.csv')

df.sample(3, random_state=RANDOM_STATE)

df['mean_metrics'] = df['mean_metrics'].apply(lambda x: ast.literal_eval(x))

df = df.sort_values(by=['mean_metrics'], ascending=True)

# %%
df.head(5)
# Out:
#      alpha_momentum  batch_size  error_decrease_tolerance  lambda_tikhonov  \
# 249             0.4           1                   0.00001           0.0001
# 48              0.6           8                   0.00001           0.0001
# 68              0.6           1                   0.00001           0.0001
# 66              0.6           1                   0.00001           0.0001
# 188             0.3           1                   0.00001           0.0001
#
#      learning_rate  max_epochs  min_epochs  patience  \
# 249            0.5         600          80        50
# 48             0.4         600          80        50
# 68             0.4         600          80        50
# 66             0.2         600          80        50
# 188            0.4         600          80        50
#
#                                               topology  \
# 249  {0: ['input_0', None, [], [17, 18, 19, 20]], 1...
# 48   {0: ['input_0', None, [], [17, 18, 19, 20]], 1...
# 68   {0: ['input_0', None, [], [17, 18, 19, 20]], 1...
# 66   {0: ['input_0', None, [], [17, 18, 19, 20]], 1...
# 188  {0: ['input_0', None, [], [17, 18, 19, 20]], 1...
#
#                                                  stats           mean_metrics  \
# 249  {'max_epochs': 600, 'training_set_len': 98, 'm...  [0.06877106846022395]
# 48   {'max_epochs': 600, 'training_set_len': 98, 'm...  [0.06927882164562793]
# 68   {'max_epochs': 600, 'training_set_len': 98, 'm...   [0.0699798654440642]
# 66   {'max_epochs': 600, 'training_set_len': 98, 'm...  [0.07002339196471286]
# 188  {'max_epochs': 600, 'training_set_len': 98, 'm...  [0.07011270521611612]
#
#              variance_metrics
# 249   [0.0004069443643033116]
# 48   [0.00025274577393038074]
# 68    [0.0008415143262094834]
# 66    [0.0009820516951231587]
# 188    [0.002034468999725124]

# %%
NN = NeuralNetwork(topology, -0.75, 0.75, False, RANDOM_STATE)

# %%
training_set = tr_df_OHE.values
validation_set = val_df_OHE.values
metrics = [ErrorFunctions.mean_squared_error, ] #ErrorFunctions.mean_euclidean_error, 

batch_size = 8
max_epochs = 600

error_decrease_tolerance = 0.00001
patience = 10
min_epochs = 80

lambda_tikhonov = 0.0001
alpha_momentum = 0.6
learning_rate = 0.4/batch_size
# beacause of the momentum is used the learning rate needs to be a little less?!?!?

collect_datas = True
collect_datas_batch = False # per il momento. molto costoso!!!! False di default
verbose = True

stats = NN.train(training_set, validation_set, batch_size, max_epochs, error_decrease_tolerance, patience, min_epochs, 
                   learning_rate,0,0, lambda_tikhonov, alpha_momentum, False,metrics, collect_datas, collect_datas_batch, verbose)
# Out:
# starting values:  {'training_set_len': 122, 'minibatch_size': 8, 'max_epochs': 600, 'error_decrease_tolerance': 1e-05, 'patience': 10, 'min_epochs': 80, 'learning_rate': 0.05, 'lambda_tikhonov': 0.0001, 'alpha_momentum': 0.6, 'nesterov': False, 'epochs': 0, 'total_train_time': datetime.timedelta(days=-1, seconds=86399, microseconds=999994), 'mean_epoch_train_time': 0, 'units_weights': {20: [], 19: [], 18: [], 17: [], 21: []}, 'units_weights_batch': {20: [], 19: [], 18: [], 17: [], 21: []}, 'training_mean_squared_error': [], 'validation_mean_squared_error': [], 'training_batch_mean_squared_error': [], 'validation_batch_mean_squared_error': []}
# [1/600] tr time: 0:00:00.046400 | mean_squared_error: tr=0.24791536267692857 val=0.2482634932976753 |
# [2/600] tr time: 0:00:00.055461 | mean_squared_error: tr=0.2430568193249594 val=0.24574571783440474 |
# [3/600] tr time: 0:00:00.039412 | mean_squared_error: tr=0.23767976338487806 val=0.24084790645339368 |
# [4/600] tr time: 0:00:00.039561 | mean_squared_error: tr=0.23187764165372876 val=0.2365194572689891 |
# [5/600] tr time: 0:00:00.042711 | mean_squared_error: tr=0.21974204682102458 val=0.22386834276551293 |
# [6/600] tr time: 0:00:00.033023 | mean_squared_error: tr=0.20721858403841784 val=0.21012771573200306 |
# [7/600] tr time: 0:00:00.033040 | mean_squared_error: tr=0.19497327107112153 val=0.1967062859143466 |
# [8/600] tr time: 0:00:00.032843 | mean_squared_error: tr=0.18587090930190509 val=0.1898430642229826 |
# [9/600] tr time: 0:00:00.037892 | mean_squared_error: tr=0.17477285162522474 val=0.17528011354297227 |
# [10/600] tr time: 0:00:00.030231 | mean_squared_error: tr=0.16920522726427556 val=0.16606041919891384 |
# [11/600] tr time: 0:00:00.028061 | mean_squared_error: tr=0.1647930464648213 val=0.1594970960722966 |
# [12/600] tr time: 0:00:00.028642 | mean_squared_error: tr=0.15939536528057752 val=0.15754752729094548 |
# [13/600] tr time: 0:00:00.030616 | mean_squared_error: tr=0.15487326214603445 val=0.1499092768959256 |
# [14/600] tr time: 0:00:00.025917 | mean_squared_error: tr=0.15331961988922352 val=0.14520011035780045 |
# [15/600] tr time: 0:00:00.030925 | mean_squared_error: tr=0.15088550325199152 val=0.1415336525991051 |
# [16/600] tr time: 0:00:00.027381 | mean_squared_error: tr=0.14513184284944303 val=0.1391253610867395 |
# [17/600] tr time: 0:00:00.030778 | mean_squared_error: tr=0.14047168198008955 val=0.1315563766039831 |
# [18/600] tr time: 0:00:00.027137 | mean_squared_error: tr=0.13965530396862205 val=0.1278364821502734 |
# [19/600] tr time: 0:00:00.026306 | mean_squared_error: tr=0.13690999686838098 val=0.12411643959968514 |
# [20/600] tr time: 0:00:00.027222 | mean_squared_error: tr=0.13008283281956443 val=0.11999799948562775 |
# [21/600] tr time: 0:00:00.031912 | mean_squared_error: tr=0.1236752534858645 val=0.11061947377241835 |
# [22/600] tr time: 0:00:00.029892 | mean_squared_error: tr=0.12265624985186811 val=0.10679535765644543 |
# [23/600] tr time: 0:00:00.026725 | mean_squared_error: tr=0.11914166919098668 val=0.1022482638306146 |
# [24/600] tr time: 0:00:00.026777 | mean_squared_error: tr=0.11193319563631747 val=0.09692578612617377 |
# [277/600] tr time: 0:00:00.027988 | mean_squared_error: tr=0.046692999126705 val=0.03741281415829209 |
# [278/600] tr time: 0:00:00.026085 | mean_squared_error: tr=0.04629739896626322 val=0.035602044734403385 |
# [279/600] tr time: 0:00:00.026085 | mean_squared_error: tr=0.047129955938374865 val=0.03598781789107072 |
# [280/600] tr time: 0:00:00.027421 | mean_squared_error: tr=0.04726734565465148 val=0.03867735797653223 |
# [281/600] tr time: 0:00:00.030599 | mean_squared_error: tr=0.046302135033938326 val=0.03728077467753698 |
# [282/600] tr time: 0:00:00.026274 | mean_squared_error: tr=0.04590157265708888 val=0.035447229726722346 |
# [283/600] tr time: 0:00:00.026813 | mean_squared_error: tr=0.04674772828851979 val=0.03586433300841558 |
# [284/600] tr time: 0:00:00.027271 | mean_squared_error: tr=0.04689990254392166 val=0.03859230298821958 |
# [285/600] tr time: 0:00:00.027604 | mean_squared_error: tr=0.04592284618835883 val=0.0371424784510886 |
# [286/600] tr time: 0:00:00.027588 | mean_squared_error: tr=0.045515450558526946 val=0.03528789202306696 |
# [287/600] tr time: 0:00:00.027655 | mean_squared_error: tr=0.04637520736935784 val=0.03573642047124922 |
# [288/600] tr time: 0:00:00.025929 | mean_squared_error: tr=0.046547748750302716 val=0.038502363165315585 |
# [289/600] tr time: 0:00:00.028384 | mean_squared_error: tr=0.04555837845882868 val=0.03700001978835763 |
# [290/600] tr time: 0:00:00.026692 | mean_squared_error: tr=0.045142773196423944 val=0.035126933202435734 |
# [291/600] tr time: 0:00:00.026740 | mean_squared_error: tr=0.04601534865839839 val=0.035605794965249425 |
# [292/600] tr time: 0:00:00.027778 | mean_squared_error: tr=0.046212821140066265 val=0.03840850936851777 |
# [293/600] tr time: 0:00:00.029969 | mean_squared_error: tr=0.045211350423959254 val=0.03685588082109426 |
# [294/600] tr time: 0:00:00.027631 | mean_squared_error: tr=0.044786725542300426 val=0.034967392861226736 |
# [295/600] tr time: 0:00:00.026039 | mean_squared_error: tr=0.04567069040398957 val=0.03547452551376411 |
# [296/600] tr time: 0:00:00.027164 | mean_squared_error: tr=0.04589636688468158 val=0.038312124877830804 |
# [297/600] tr time: 0:00:00.029241 | mean_squared_error: tr=0.044883566857613834 val=0.03671265678674169 |
# [298/600] tr time: 0:00:00.028249 | mean_squared_error: tr=0.04444966203131501 val=0.0348121185044414 |
# [299/600] tr time: 0:00:00.027924 | mean_squared_error: tr=0.04534315514059827 val=0.035344790807041726 |
# [300/600] tr time: 0:00:00.027324 | mean_squared_error: tr=0.04559895494841195 val=0.03821483771565566 |
# [301/600] tr time: 0:00:00.027599 | mean_squared_error: tr=0.044575982201672484 val=0.03657276898130501 |
# [302/600] tr time: 0:00:00.027709 | mean_squared_error: tr=0.04413300354190763 val=0.03466349979000774 |
# [303/600] tr time: 0:00:00.027203 | mean_squared_error: tr=0.045033971211425765 val=0.035218635055327734 |
# [304/600] tr time: 0:00:00.028223 | mean_squared_error: tr=0.04532057145291242 val=0.03811831527146093 |
# [305/600] tr time: 0:00:00.028654 | mean_squared_error: tr=0.04428878594585917 val=0.03643824231471865 |
# [478/600] tr time: 0:00:00.029139 | mean_squared_error: tr=0.03978521137130352 val=0.033184104753462465 |
# [479/600] tr time: 0:00:00.029042 | mean_squared_error: tr=0.040893989890498285 val=0.034024866701718434 |
# [480/600] tr time: 0:00:00.027532 | mean_squared_error: tr=0.04131394614541048 val=0.036996015858978076 |
# [481/600] tr time: 0:00:00.029325 | mean_squared_error: tr=0.040075425943550076 val=0.03461743951015798 |
# [482/600] tr time: 0:00:00.027650 | mean_squared_error: tr=0.039752395859667486 val=0.0331815057196955 |
# [483/600] tr time: 0:00:00.030071 | mean_squared_error: tr=0.04087231197864059 val=0.03402794905349736 |
# [484/600] tr time: 0:00:00.027862 | mean_squared_error: tr=0.041280816938202396 val=0.036993432693336985 |
# [485/600] tr time: 0:00:00.031570 | mean_squared_error: tr=0.04003416435972998 val=0.03459340982527022 |
# [486/600] tr time: 0:00:00.031364 | mean_squared_error: tr=0.03971989565271973 val=0.03317873595209711 |
# [487/600] tr time: 0:00:00.029637 | mean_squared_error: tr=0.04085105297113771 val=0.03403069953782646 |
# [488/600] tr time: 0:00:00.029968 | mean_squared_error: tr=0.04124782531697219 val=0.036990394190681064 |
# [489/600] tr time: 0:00:00.032929 | mean_squared_error: tr=0.03999299679606642 val=0.034568686660703875 |
# [490/600] tr time: 0:00:00.031031 | mean_squared_error: tr=0.03968764404309935 val=0.03317574987507012 |
# [491/600] tr time: 0:00:00.029103 | mean_squared_error: tr=0.040830124566551045 val=0.03403305031641207 |
# [492/600] tr time: 0:00:00.027988 | mean_squared_error: tr=0.04121490418441589 val=0.03698685179770817 |
# [493/600] tr time: 0:00:00.028891 | mean_squared_error: tr=0.03995186695516848 val=0.03454323953708077 |
# [494/600] tr time: 0:00:00.029674 | mean_squared_error: tr=0.03965557752267127 val=0.03317250392913965 |
# [495/600] tr time: 0:00:00.027938 | mean_squared_error: tr=0.040809440535479476 val=0.034034934299249024 |
# [496/600] tr time: 0:00:00.027843 | mean_squared_error: tr=0.041181989883079535 val=0.03698275938152297 |
# [497/600] tr time: 0:00:00.028941 | mean_squared_error: tr=0.03991072211553323 val=0.03451704128417247 |
# [498/600] tr time: 0:00:00.027269 | mean_squared_error: tr=0.0396236355113142 val=0.033168956564904616 |
# [499/600] tr time: 0:00:00.029377 | mean_squared_error: tr=0.04078891642241651 val=0.034036285218206376 |
# [500/600] tr time: 0:00:00.027375 | mean_squared_error: tr=0.04114902200143891 val=0.03697807322449046 |
# [501/600] tr time: 0:00:00.028672 | mean_squared_error: tr=0.03986951301784483 val=0.03449006817921757 |
# [502/600] tr time: 0:00:00.028367 | mean_squared_error: tr=0.039591760120845386 val=0.03316506825357796 |
# [503/600] tr time: 0:00:00.028235 | mean_squared_error: tr=0.040768469309966686 val=0.03403703776448634 |
# [504/600] tr time: 0:00:00.027821 | mean_squared_error: tr=0.04111594323591738 val=0.03697275209647493 |
# [505/600] tr time: 0:00:00.031244 | mean_squared_error: tr=0.03982819379188493 val=0.034462300125212425 |
# [506/600] tr time: 0:00:00.027781 | mean_squared_error: tr=0.03955989596719732 val=0.033160801529280345 |
# [507/600] tr time: 0:00:00.028867 | mean_squared_error: tr=0.040748017661946925 val=0.03403712780760623 |
# [508/600] tr time: 0:00:00.027290 | mean_squared_error: tr=0.041082699316763324 val=0.03696675741301064 |
# [509/600] tr time: 0:00:00.029632 | mean_squared_error: tr=0.03978672192967523 val=0.03443372087343504 |
# [510/600] tr time: 0:00:00.027616 | mean_squared_error: tr=0.039527990042119154 val=0.03315612107625213 |
# [511/600] tr time: 0:00:00.029787 | mean_squared_error: tr=0.04072748125864221 val=0.034036492707718344 |
# [512/600] tr time: 0:00:00.028259 | mean_squared_error: tr=0.04104923900114693 val=0.03696005348083859 |
# [513/600] tr time: 0:00:00.029528 | mean_squared_error: tr=0.039745058307421144 val=0.03440431829068816 |
# [514/600] tr time: 0:00:00.027168 | mean_squared_error: tr=0.03949599165299234 val=0.03315099387079452 |
# [515/600] tr time: 0:00:00.027701 | mean_squared_error: tr=0.04070678123545522 val=0.034035071731187985 |
# [516/600] tr time: 0:00:00.027495 | mean_squared_error: tr=0.041015514134003166 val=0.036952607828799555 |
# [517/600] tr time: 0:00:00.029881 | mean_squared_error: tr=0.03970316725566245 val=0.0343740846687867 |
# [518/600] tr time: 0:00:00.028544 | mean_squared_error: tr=0.03946385243549658 val=0.03314538938371007 |
# [519/600] tr time: 0:00:00.027450 | mean_squared_error: tr=0.04068584023102108 val=0.034032806571951554 |
# [520/600] tr time: 0:00:00.027460 | mean_squared_error: tr=0.04098147977144912 val=0.036944391614289 |
# [521/600] tr time: 0:00:00.029171 | mean_squared_error: tr=0.03966101667328364 val=0.034343017069620764 |
# [522/600] tr time: 0:00:00.027233 | mean_squared_error: tr=0.039431526439646813 val=0.03313927984468346 |
# [523/600] tr time: 0:00:00.028488 | mean_squared_error: tr=0.04066458264619438 val=0.03402964197630975 |
# [524/600] tr time: 0:00:00.027522 | mean_squared_error: tr=0.040947094358154336 val=0.0369353800913152 |
# [525/600] tr time: 0:00:00.029237 | mean_squared_error: tr=0.03961857817702706 val=0.03431111769540932 |
# [526/600] tr time: 0:00:00.027333 | mean_squared_error: tr=0.03939897028460909 val=0.03313264056426788 |
# [527/600] tr time: 0:00:00.027072 | mean_squared_error: tr=0.04064293500906147 val=0.034025526460694025 |
# [528/600] tr time: 0:00:00.027399 | mean_squared_error: tr=0.040912319945125925 val=0.036925553120114064 |
# [529/600] tr time: 0:00:00.030937 | mean_squared_error: tr=0.039575827274453225 val=0.034278394269534926 |
# [530/600] tr time: 0:00:00.028007 | mean_squared_error: tr=0.03936614337266805 val=0.03312545030427641 |
# [531/600] tr time: 0:00:00.027443 | mean_squared_error: tr=0.04062082643503846 val=0.03402041310581053 |
# [532/600] tr time: 0:00:00.027610 | mean_squared_error: tr=0.040877122430843224 val=0.03691489569441289 |
# [533/600] tr time: 0:00:00.028958 | mean_squared_error: tr=0.03953274354479147 val=0.03424486040999121 |
# [534/600] tr time: 0:00:00.026819 | mean_squared_error: tr=0.03933300814776889 val=0.033117691682081125 |
# [535/600] tr time: 0:00:00.028334 | mean_squared_error: tr=0.04059818916422452 val=0.03401426040263221 |
# [536/600] tr time: 0:00:00.027043 | mean_squared_error: tr=0.040841471805821 val=0.036903398459109525 |
# [537/600] tr time: 0:00:00.028757 | mean_squared_error: tr=0.03948931080981832 val=0.03421053597468802 |
# [538/600] tr time: 0:00:00.026978 | mean_squared_error: tr=0.039299530379755816 val=0.03310935159012502 |
# [539/600] tr time: 0:00:00.027165 | mean_squared_error: tr=0.04057495915324024 val=0.03400703312118714 |
# [540/600] tr time: 0:00:00.027133 | mean_squared_error: tr=0.04080534237947493 val=0.03689105819058686 |
# [541/600] tr time: 0:00:00.029796 | mean_squared_error: tr=0.039445517275348334 val=0.03417544735617119 |
# [542/600] tr time: 0:00:00.027985 | mean_squared_error: tr=0.03926567945211435 val=0.03310042160808371 |
# [543/600] tr time: 0:00:00.026969 | mean_squared_error: tr=0.04055107669316691 val=0.03399870316721133 |
# [544/600] tr time: 0:00:00.026951 | mean_squared_error: tr=0.04076871296761783 val=0.036877878211573636 |
# [545/600] tr time: 0:00:00.028780 | mean_squared_error: tr=0.0394013556239348 val=0.03413962770280803 |
# [546/600] tr time: 0:00:00.027074 | mean_squared_error: tr=0.03923142862941625 val=0.033090898384073114 |
# [547/600] tr time: 0:00:00.028309 | mean_squared_error: tr=0.04052648702249102 val=0.033989250390056056 |
# [548/600] tr time: 0:00:00.027358 | mean_squared_error: tr=0.040731567020691535 val=0.03686386871531043 |
# [549/600] tr time: 0:00:00.028503 | mean_squared_error: tr=0.03935682304083063 val=0.0341031170448704 |
# [550/600] tr time: 0:00:00.026777 | mean_squared_error: tr=0.039196755280328385 val=0.03308078396011241 |
# [551/600] tr time: 0:00:00.027048 | mean_squared_error: tr=0.04050114090248737 val=0.03397866330468892 |
# [552/600] tr time: 0:00:00.027160 | mean_squared_error: tr=0.04069389267566018 val=0.036849046978108355 |
# [553/600] tr time: 0:00:00.029605 | mean_squared_error: tr=0.03931192115812538 val=0.03406596230689686 |
# [554/600] tr time: 0:00:00.027030 | mean_squared_error: tr=0.03916164103395528 val=0.033070086019682136 |
# [555/600] tr time: 0:00:00.027068 | mean_squared_error: tr=0.04047499512270778 val=0.033966939692132964 |
# [556/600] tr time: 0:00:00.027087 | mean_squared_error: tr=0.040655682718457486 val=0.0368334374445611 |
# [557/600] tr time: 0:00:00.028546 | mean_squared_error: tr=0.03926665590593575 val=0.03402821719188848 |
# [558/600] tr time: 0:00:00.027080 | mean_squared_error: tr=0.03912607185057221 val=0.03305881803827807 |
# [559/600] tr time: 0:00:00.028147 | mean_squared_error: tr=0.0404480129077157 val=0.033954087048262645 |
# [560/600] tr time: 0:00:00.027150 | mean_squared_error: tr=0.040616934449017726 val=0.0368170716768405 |
# [561/600] tr time: 0:00:00.028396 | mean_squared_error: tr=0.03922103726477622 val=0.033989941929527596 |
# [562/600] tr time: 0:00:00.027099 | mean_squared_error: tr=0.03909003799271236 val=0.03304699932345397 |
# [563/600] tr time: 0:00:00.027085 | mean_squared_error: tr=0.04042016419984526 val=0.03394012285654163 |
# [564/600] tr time: 0:00:00.026893 | mean_squared_error: tr=0.04057764944605624 val=0.03679998816642592 |
# [565/600] tr time: 0:00:00.029735 | mean_squared_error: tr=0.039175078918563366 val=0.03395120288716498 |
# [566/600] tr time: 0:00:00.026981 | mean_squared_error: tr=0.039053533888486175 val=0.033034654937508866 |
# [567/600] tr time: 0:00:00.027007 | mean_squared_error: tr=0.04039142579942131 val=0.03392507466949661 |
# [568/600] tr time: 0:00:00.027286 | mean_squared_error: tr=0.0405378332340315 val=0.036782232013630525 |
# [569/600] tr time: 0:00:00.028439 | mean_squared_error: tr=0.03912879781308495 val=0.0339120720498428 |
# [570/600] tr time: 0:00:00.027114 | mean_squared_error: tr=0.039016557885042734 val=0.03302181550262264 |
# [571/600] tr time: 0:00:00.027735 | mean_squared_error: tr=0.04036178135074996 val=0.03390897999286715 |
# [572/600] tr time: 0:00:00.027246 | mean_squared_error: tr=0.0404974948596077 val=0.03676385448743298 |
# [573/600] tr time: 0:00:00.028700 | mean_squared_error: tr=0.03908221362996595 val=0.03387262638324228 |
# [574/600] tr time: 0:00:00.027014 | mean_squared_error: tr=0.038979111896457 val=0.03300851689610491 |
# [575/600] tr time: 0:00:00.026988 | mean_squared_error: tr=0.040331221169138655 val=0.0338918859761509 |
# [576/600] tr time: 0:00:00.029288 | mean_squared_error: tr=0.04045664638852677 val=0.03674491248288339 |
# [577/600] tr time: 0:00:00.032557 | mean_squared_error: tr=0.039035348189952544 val=0.03383294709991385 |
# [578/600] tr time: 0:00:00.029132 | mean_squared_error: tr=0.038941200955543445 val=0.03299479984920749 |
# [579/600] tr time: 0:00:00.027838 | mean_squared_error: tr=0.040299741912134666 val=0.033873848922893204 |
# [580/600] tr time: 0:00:00.027241 | mean_squared_error: tr=0.04041530233672451 val=0.03672546789818864 |
# [581/600] tr time: 0:00:00.030022 | mean_squared_error: tr=0.03898822480218755 val=0.03379311885390599 |
# [582/600] tr time: 0:00:00.029282 | mean_squared_error: tr=0.038902832683349826 val=0.03298070946844543 |
# [583/600] tr time: 0:00:00.030431 | mean_squared_error: tr=0.04026734610390307 val=0.03385493364194806 |
# [584/600] tr time: 0:00:00.029747 | mean_squared_error: tr=0.04037347905113814 val=0.03670558695592968 |
# [585/600] tr time: 0:00:00.030170 | mean_squared_error: tr=0.0389408675776258 val=0.03375322889260362 |
# [586/600] tr time: 0:00:00.027573 | mean_squared_error: tr=0.03886401669314631 val=0.03296629470147035 |
# [587/600] tr time: 0:00:00.027656 | mean_squared_error: tr=0.04023404152791461 val=0.03383521266752663 |
# [588/600] tr time: 0:00:00.028555 | mean_squared_error: tr=0.040331194055889745 val=0.036685339493617346 |
# [589/600] tr time: 0:00:00.030648 | mean_squared_error: tr=0.03889330072483451 val=0.03371336619564189 |
# [590/600] tr time: 0:00:00.029268 | mean_squared_error: tr=0.03882476394694277 val=0.03295160777112623 |
# [591/600] tr time: 0:00:00.027154 | mean_squared_error: tr=0.04019984050675388 val=0.033814765380072845 |
# [592/600] tr time: 0:00:00.028997 | mean_squared_error: tr=0.040288465379538584 val=0.03666479824912284 |
# [593/600] tr time: 0:00:00.031754 | mean_squared_error: tr=0.0388455478452694 val=0.033673620629777835 |
# [594/600] tr time: 0:00:00.028068 | mean_squared_error: tr=0.038785086082827075 val=0.03293670360074789 |
# [595/600] tr time: 0:00:00.029910 | mean_squared_error: tr=0.040164759090853715 val=0.033793677061805236 |
# [596/600] tr time: 0:00:00.028939 | mean_squared_error: tr=0.040245310877277056 val=0.03664403816350667 |
# [597/600] tr time: 0:00:00.029634 | mean_squared_error: tr=0.03879763124333822 val=0.033634082145957506 |
# [598/600] tr time: 0:00:00.028680 | mean_squared_error: tr=0.038744994730391086 val=0.03292163925191199 |
# [599/600] tr time: 0:00:00.030001 | mean_squared_error: tr=0.04012881617970807 val=0.033772037921441615 |
# [600/600] tr time: 0:00:00.031656 | mean_squared_error: tr=0.04020174756112456 val=0.036623135722356766 |

# %%
tr_predictions = NN.predict_array(training_set[:,:TR_INPUT])
val_predictions = NN.predict_array(validation_set[:,:TR_INPUT])

# %%
pd.options.mode.chained_assignment = None
prediction_col = ['prediction_1']#, 'prediction_2', 'prediction_3']
for col in prediction_col:
    tr_df[prediction_col] = np.array([[1] if x > 0.5 else [0] for x in tr_predictions])
    tr_df[col + '_err'] = (tr_df[col] - tr_df['output_' + col[-1]])**2

# %%
tr_df['prediction_1_err'].max()
# Out:
# 1

# %%
tr_df.sample(5, random_state=RANDOM_STATE)
# Out:
#     input_1  input_2  input_3  input_4  input_5  input_6  output_1  \
# 93        3        1        1        3        4        2         0
# 16        1        1        2        3        3        2         1
# 17        1        2        1        1        3        1         1
# 95        3        1        2        2        3        2         1
# 35        1        3        1        1        2        1         0
#
#     prediction_1  prediction_1_err
# 93             0                 0
# 16             1                 0
# 17             1                 0
# 95             1                 0
# 35             0                 0

# %%
val_df[prediction_col] = val_predictions
for col in prediction_col:
    val_df[prediction_col] = np.array([[1] if x > 0.5 else [0] for x in val_predictions])
    val_df[col + '_err'] = (val_df[col] - val_df['output_' + col[-1]])**2

# %%
val_df.sample(5, random_state=RANDOM_STATE)
# Out:
#      input_1  input_2  input_3  input_4  input_5  input_6  output_1  \
# 173        2        1        2        1        3        2         1
# 91         1        2        2        3        2        2         1
# 105        1        3        1        2        1        2         0
# 431        3        3        2        3        4        2         0
# 389        3        3        1        1        3        2         1
#
#      prediction_1  prediction_1_err
# 173             1                 0
# 91              1                 0
# 105             0                 0
# 431             0                 0
# 389             1                 0

# %%
print('training accuracy =', (tr_df['output_1'] == tr_df['prediction_1']).sum() / len(tr_df))
print('validation accuracy =', (val_df['output_1'] == val_df['prediction_1']).sum() / len(val_df))
# Out:
# training accuracy = 0.9754098360655737
# validation accuracy = 0.9629629629629629

# %%
print('misclassified =', (tr_df['output_1'] != tr_df['prediction_1']).sum(), 'su', len(tr_df))
print('misclassified =', (val_df['output_1'] != val_df['prediction_1']).sum(), 'su', len(val_df))
# Out:
# misclassified = 3 su 122
# misclassified = 16 su 432

# %%
for key in list(stats.keys())[:12]:
    print(key, ':', stats[key])
# Out:
# training_set_len : 122
# minibatch_size : 8
# max_epochs : 600
# error_decrease_tolerance : 1e-05
# patience : 10
# min_epochs : 80
# learning_rate : 0.05
# lambda_tikhonov : 0.0001
# alpha_momentum : 0.6
# nesterov : False
# epochs : 600
# total_train_time : 0:00:17.273147

# %%
for met in metrics:
    print('last training ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
    print('last validation ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
# Out:
# last training mean_squared_error : 0.04020174756112456
# last validation mean_squared_error : 0.04020174756112456

# %%
for met in metrics:
    print('last training ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
    print('last validation ' + met.__name__ + ' :', stats['training_' + met.__name__][-1])
# Out:
# last training mean_squared_error : 0.04020174756112456
# last validation mean_squared_error : 0.04020174756112456

# %%
if len(metrics) > 1:
    fig, ax = plt.subplots(1, len(metrics), figsize=(10, 5))
    plt.suptitle('Training Metrics (epochs)')
    for i in range(len(metrics)):
        multy_plot([stats['training_' + metrics[i].__name__], stats['validation_' + metrics[i].__name__]], 
                ['training_' + metrics[i].__name__, 'validation_' + metrics[i].__name__],
                ax=ax[i])
else:
    plt.suptitle('Training Metrics (epochs)')
    multy_plot([stats['training_' + metrics[0].__name__], stats['validation_' + metrics[0].__name__]], 
                ['training_' + metrics[0].__name__, 'validation_' + metrics[0].__name__])

# %%
'''plt.suptitle('Training Metrics (epochs)')
for i in range(len(metrics)):
    multy_plot([stats_0['training_' + metrics[i].__name__], stats_0['validation_' + metrics[i].__name__]] + 
               [stats_1['training_' + metrics[i].__name__], stats_1['validation_' + metrics[i].__name__]] +
               [stats_2['training_' + metrics[i].__name__], stats_2['validation_' + metrics[i].__name__]] +
               [stats_3['training_' + metrics[i].__name__], stats_3['validation_' + metrics[i].__name__]],
            ['tr_0.0', 'val_0.0', 'tr_0.25', 'val_0.25', 'tr_0.5', 'val_0.5', 'tr_0.75', 'val_0.75', 'tr_0.95', 'val_0.95',], 
            title='Training Metrics (epochs)')'''
# Out:
# "plt.suptitle('Training Metrics (epochs)')\nfor i in range(len(metrics)):\n    multy_plot([stats_0['training_' + metrics[i].__name__], stats_0['validation_' + metrics[i].__name__]] + \n               [stats_1['training_' + metrics[i].__name__], stats_1['validation_' + metrics[i].__name__]] +\n               [stats_2['training_' + metrics[i].__name__], stats_2['validation_' + metrics[i].__name__]] +\n               [stats_3['training_' + metrics[i].__name__], stats_3['validation_' + metrics[i].__name__]],\n            ['tr_0.0', 'val_0.0', 'tr_0.25', 'val_0.25', 'tr_0.5', 'val_0.5', 'tr_0.75', 'val_0.75', 'tr_0.95', 'val_0.95',], \n            title='Training Metrics (epochs)')"

# %%
if len(metrics) > 1:
    fig, ax = plt.subplots(1, len(metrics), figsize=(10, 5))
    plt.suptitle('Learning Curve (batch)')
    for i in range(len(metrics)):
        multy_plot([stats['training_batch_' + metrics[i].__name__], stats['validation_batch_' + metrics[i].__name__]], 
                ['training_batch_' + metrics[i].__name__, 'validation_batch_' + metrics[i].__name__],
                ax=ax[i])
    plt.show()
else:
    plt.suptitle('Training Metrics (batch)')
    multy_plot([stats['training_batch_' + metrics[0].__name__], stats['validation_batch_' + metrics[0].__name__]], 
                ['training_batch_' + metrics[0].__name__, 'validation_batch_' + metrics[0].__name__])

# %%
'''plt.suptitle('Training Metrics (epochs)')
for i in range(len(metrics)):
    multy_plot([stats_0['training_batch_' + metrics[i].__name__], stats_0['validation_batch_' + metrics[i].__name__]] + 
               [stats_1['training_batch_' + metrics[i].__name__], stats_1['validation_batch_' + metrics[i].__name__]] +
               [stats_2['training_batch_' + metrics[i].__name__], stats_2['validation_batch_' + metrics[i].__name__]] +
               [stats_3['training_batch_' + metrics[i].__name__], stats_3['validation_batch_' + metrics[i].__name__]] + 
               [stats_4['training_batch_' + metrics[i].__name__], stats_4['validation_batch_' + metrics[i].__name__]],
            ['tr_0.0', 'val_0.0', 'tr_0.25', 'val_0.25', 'tr_0.5', 'val_0.5', 'tr_0.75', 'val_0.75', 'tr_0.95', 'val_0.95',], 
            title='Training Metrics (epochs)')'''
# Out:
# "plt.suptitle('Training Metrics (epochs)')\nfor i in range(len(metrics)):\n    multy_plot([stats_0['training_batch_' + metrics[i].__name__], stats_0['validation_batch_' + metrics[i].__name__]] + \n               [stats_1['training_batch_' + metrics[i].__name__], stats_1['validation_batch_' + metrics[i].__name__]] +\n               [stats_2['training_batch_' + metrics[i].__name__], stats_2['validation_batch_' + metrics[i].__name__]] +\n               [stats_3['training_batch_' + metrics[i].__name__], stats_3['validation_batch_' + metrics[i].__name__]] + \n               [stats_4['training_batch_' + metrics[i].__name__], stats_4['validation_batch_' + metrics[i].__name__]],\n            ['tr_0.0', 'val_0.0', 'tr_0.25', 'val_0.25', 'tr_0.5', 'val_0.5', 'tr_0.75', 'val_0.75', 'tr_0.95', 'val_0.95',], \n            title='Training Metrics (epochs)')"

# %%
for unit_index in stats['units_weights'].keys():
    vals = np.array(stats['units_weights'][unit_index]).T
    multy_plot(vals, 
               ['weight_' + str(i) for i in range(len(vals))], 
               'Unit ' + str(unit_index) + ' Weights (unit type: ' + NN.neurons[unit_index].type + ')')

# %%
for i in range(TR_OUTPUT):
    sorted_order = training_set[:, TR_INPUT + i].argsort()
    multy_plot([tr_df['prediction_1'].values[sorted_order] , tr_df['output_1'].values[sorted_order]], 
                ['output_val', 'target_val'], 
                'NN Output_' + str(i + 1) +  ' Values')

# %%
for i in range(TR_OUTPUT):
    sorted_order = validation_set[:, TR_INPUT + i].argsort()
    multy_plot([val_df['prediction_1'].values[sorted_order] , val_df['output_1'].values[sorted_order]], 
                ['output_val', 'target_val'], 
                'NN Output_' + str(i + 1) +  ' Values')
