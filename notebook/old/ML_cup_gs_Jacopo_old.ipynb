# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import pandas as pd
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler, StandardScaler

sys.path.append(os.path.abspath('../src/'))
from ModelSelection import *
from ActivationFunctions import *
from NeuralNetwork import *
from MyUtils import *

# %%
cup_df = pd.read_csv(
    '../data/ML-CUP23-TR.csv',
    index_col=0,
    comment='#',
    header=None,
    names=['feature_' + str(i+1) for i in range(10)] + ['target_' + str(i+1) for i in range(3)]
)

data_set = cup_df.values
len_data = len(data_set)
np.random.shuffle(data_set)

training_len = int(0.8*len_data)

training_set = data_set[:int(training_len)] # Training Set for KFold Cross Validation
test_set = data_set[int(training_len):] # Hold Out Test Set

TR_OUTPUT = 3
TR_INPUT = data_set.shape[1] - TR_OUTPUT

scaler_out = StandardScaler()
scaler_in = StandardScaler()
scaler_in.fit(training_set[:,:TR_INPUT])
scaler_out.fit(training_set[:,TR_INPUT:])

tr_normalized = np.empty((training_len, TR_OUTPUT + TR_INPUT))
tr_normalized[:,:TR_INPUT] = scaler_in.transform(training_set[:,:TR_INPUT])
tr_normalized[:,TR_INPUT:] = scaler_out.transform(training_set[:,TR_INPUT:])

test_normalized = np.empty((len_data - training_len, TR_OUTPUT + TR_INPUT))
test_normalized[:,:TR_INPUT] = scaler_in.transform(test_set[:,:TR_INPUT])
test_normalized[:,TR_INPUT:] = scaler_out.transform(test_set[:,TR_INPUT:])

# %%
hidden_len = 32

hidden_fun = 'tanh'
output_fun = 'identity'

tanh_l1 = create_stratified_topology([TR_INPUT,hidden_len,TR_OUTPUT], 
                                      [[None,[]]]*TR_INPUT + [[hidden_fun, [1]]]*hidden_len + [[output_fun, []]]*TR_OUTPUT)

hidden_fun = 'sigmoid'
output_fun = 'identity'

sigmoid_l1 = create_stratified_topology([TR_INPUT,hidden_len,TR_OUTPUT], 
                                      [[None,[]]]*TR_INPUT + [[hidden_fun, [1]]]*hidden_len + [[output_fun, []]]*TR_OUTPUT)

# %%
NeuralNetwork.display_topology(tanh_l1)

# %%
MS = ModelSelection('../data/gs_data/1l_tanh_2.csv')
MS.default_values["metrics"] = [ErrorFunctions.mean_euclidean_error, ErrorFunctions.mean_squared_error]

hyperparam_grid = {
    'adamax' : [True, False],
    'adamax_learning_rate' : [0.01, 0.05, 0.03, 0.07],
    'exp_decay_rate_1':[0.9, 0.95],
    'exp_decay_rate_2':[0.999],
    
    'learning_rate':[0.01, 0.1, 0.2],
    'lr_decay_tau':[250],
    'lambda_tikhonov':[0.00001, 0.0001],
    'alpha_momentum':[0.1, 0.5, 0.9],
    'batch_size':[int(training_len/20), int(training_len/40)],
    'min_epochs': [100],
    'max_epochs':[600],
    
    'error_increase_tolerance':[0.00001],
    'patience':[8],
    'topology': [str(tanh_l1)],
}

c1 = lambda x: x
constr = {'adamax': (c1, ['learning_rate', 'alpha_momentum', 'lr_decay_tau'], ['adamax_learning_rate', 'exp_decay_rate_1', 'exp_decay_rate_2'])}

MS.grid_searchKF(tr_normalized, hyperparam_grid, 3, 12, True, constr)
# Out:
# Already done:  51
# tot conf: 68
# remaining conf: 17
# tot conf to do: 17
# pid: 14576  started new kfold 1 / 2
# pid: 14601  started new kfold 1 / 2
# pid: 14635  started new kfold 1 / 2
# pid: 14660  started new kfold 1 / 2
# pid: 14685  started new kfold 1 / 2
# pid: 14716  started new kfold 1 / 2
# pid: 14741  started new kfold 1 / 2
# pid: 14769  started new kfold 1 / 1
# pid: 14800  started new kfold 1 / 1
# pid: 14825  started new kfold 1 / 1
# pid: 14635  started new kfold 2 / 2
# pid: 14716  started new kfold 2 / 2
# pid: 14601  started new kfold 2 / 2
# pid: 14685  started new kfold 2 / 2
# pid: 14576  started new kfold 2 / 2
# pid: 14660  started new kfold 2 / 2
# pid: 14741  started new kfold 2 / 2

# %%
hidden_len = 24

hidden_fun = 'tanh'
output_fun = 'identity'

tanh_l1_small = create_stratified_topology([TR_INPUT,hidden_len,TR_OUTPUT], 
                                      [[None,[]]]*TR_INPUT + [[hidden_fun, [1]]]*hidden_len + [[output_fun, []]]*TR_OUTPUT)

# %%
NeuralNetwork.display_topology(tanh_l1_small)

# %%
MS = ModelSelection('../data/1l_tanh_2_small.csv')

hyperparam_grid = {
    'learning_rate':[0.01, 0.1, 0.2],
    'lr_decay_tau':[250],
    'adamax' : [True, False],
    'adamax_learning_rate' : [0.01, 0.05, 0.03, 0.07],
    'exp_decay_rate_1':[0.9, 0.95],
    'exp_decay_rate_2':[0.999],
    'alpha_momentum':[0.1, 0.5, 0.9],
    'lambda_tikhonov':[0.00001, 0.0001],
    'batch_size':[int(training_len/20), int(training_len/40)],
    'min_epochs': [100],
    'max_epochs':[600],
    'metrics':[[ErrorFunctions.mean_euclidean_error, ErrorFunctions.mean_squared_error]],
    'error_increase_tolerance':[0.00001],
    'patience':[8],
    'topology': [str(tanh_l1_small)],
}

c1 = lambda x: x
constr = {'adamax': (c1, ['learning_rate', 'alpha_momentum', 'lr_decay_tau'], ['adamax_learning_rate', 'exp_decay_rate_1', 'exp_decay_rate_2'])}

MS.grid_searchKF(tr_normalized, hyperparam_grid, constr, 3, 5, False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 24
#      21 c1 = lambda x: x
#      22 constr = {'adamax': (c1, ['learning_rate', 'alpha_momentum', 'lr_decay_tau'], ['adamax_learning_rate', 'exp_decay_rate_1', 'exp_decay_rate_2'])}
# ---> 24 MS.grid_searchKF(tr_normalized, hyperparam_grid, constr, 3, 5, False)
#
# File ~/ML_Proj_NN/src/ModelSelection.py:363, in grid_searchKF(self, data_set, hyperparameters, k_folds, n_proc, recovery, constraints)
#     349 def grid_searchKF(self, data_set:np.ndarray, hyperparameters:dict = {}, k_folds:int = 2, n_proc:int = 1, recovery:bool = False, constraints:dict = {}, ):
#     350     '''
#     351     Implementation of the grid search algorithm
#     352
#    (...)
#     360     return: the best hyperparameters' configuration
#     361     '''
# --> 363     hyperparameters = dict(sorted(hyperparameters.items()))
#     364     configurations, names = self.__get_configurations(hyperparameters, constraints, recovery)
#     365     print('tot conf to do:', len(configurations))
#
# File ~/ML_Proj_NN/src/ModelSelection.py:216, in ModelSelection.__get_configurations(self, hyperparameters, constraints, recovery)
#     214 done_configurations = []
#     215 if recovery:
# --> 216     done_configurations, success = self.__restore_backup(list(hyperparameters.keys()))
#     218     if not success:
#     219         Raise(ValueError('The specified hyperparameters not correspond to backup data found'))
#
# File ~/ML_Proj_NN/src/ModelSelection.py:190, in ModelSelection.__restore_backup(self, hyperparameters)
#     180 '''
#     181 Restore model selection's state from a backup file (csv format)
#     182
#    (...)
#     185 return: -
#     186 '''
#     188 restore_file = self.__merge_csv_file(os.path.join(self.partials_backup_path, self.partials_backup_prefix + "0.csv"))
# --> 190 csv = pandas.read_csv(restore_file)
#     192 stats_columns = csv.columns.get_loc("stats")
#     193 columns_to_drop = list(csv.columns[stats_columns:])
#
# File ~/ML_Proj_NN/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/ML_Proj_NN/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/ML_Proj_NN/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/ML_Proj_NN/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/ML_Proj_NN/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/gs_data/backup/tmp_0.csv'
