# %%
import matplotlib.pyplot as plt
import numpy

a = []
b = []
alpha = 3

for i in range(-500, 500):
    dummy = ((i/100)*alpha)/2
    a.append(dummy)
    b.append(numpy.tanh(dummy))

plt.scatter(a,b)
